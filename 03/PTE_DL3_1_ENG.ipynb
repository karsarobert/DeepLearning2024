# %% [markdown]
# <a href="https://colab.research.google.com/github/karsarobert/DeepLearning2024/blob/main/03/PTE_DL3_1_ENG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning practice
#
#
# ## 3. praktice: gradient descent
# ### 18th of September 2024

# %% [markdown]
# # Linear regression
# ## Predicting your essay score based on the time spent studying
#
# forrás: https://github.com/kaustubholpadkar/

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read Data

# %%
data = np.genfromtxt('https://raw.githubusercontent.com/kaustubholpadkar/Linear_Regression-Gradient_Descent-Octave/master/data.csv', delimiter=',')

# %%
data.shape #adatok alakja 100 tanulóadat
# Out:
# (100, 2)

# %%
data[:5,:] #az első 5 adatsor elsőoszlop az X bemenet második oszlop y kimenet
# Out:
# array([[32.50234527, 31.70700585],
#        [53.42680403, 68.77759598],
#        [61.53035803, 62.5623823 ],
#        [47.47563963, 71.54663223],
#        [59.81320787, 87.23092513]])

# %% [markdown]
# ### Seperate Data into X and Y

# %%
X = data[:, 0]
Y = data[:, 1]

# %% [markdown]
# ### Visualize the Data

# %%
fig = plt.figure()
plt.scatter(X, Y)
fig.suptitle('Student Data : Expected Marks vs Hours of Study', fontsize=18)
plt.xlabel('Hours of Study', fontsize=14)
plt.ylabel('Expected Marks', fontsize=14)
plt.show()

# %% [markdown]
# ### Hyperparameters

# %%
learning_rate = 0.0001
max_iteration = 50

# %% [markdown]
# ### Parameters

# %%
m = 1
b = 1

# %% [markdown]
# ### Hypothesis

# %%
def h (m, b, X) :
  return m * X + b

# %% [markdown]
# ### Loss Function

# %%
def loss (m, b, X, Y) :
  return np.average(np.square(Y - h(m, b, X))) / 2

# %% [markdown]
# ### Calculate Gradients

# %%
def gradient (m, b, X, Y) :
  dm = - np.average((Y - h(m, b, X)) * X) # loss függvény m szerinti deriváltja
  db = - np.average(Y - h(m, b, X)) # loss függvény b szerinti deriváltja
  return (dm, db)

# %%
print(Y[:3], h(m, b, X)[:3])
# Out:
# [31.70700585 68.77759598 62.5623823 ] [33.50234527 54.42680403 62.53035803]

# %% [markdown]
# ### Gradient Descent

# %%
def gradient_descent (m, b, X, Y, learning_rate, max_iteration) :
  for i in range(max_iteration) :
    dm, db = gradient (m, b, X, Y)
    m -= learning_rate * dm
    b -= learning_rate * db
    if i % 10 == 0 :
      print ('iteration : ', i, ' loss : ', loss(m, b, X, Y))
  return (m, b)

# %% [markdown]
# ### Train Model

# %%
m, b = gradient_descent (m, b, X, Y, learning_rate, max_iteration)
# Out:
# iteration :  0  loss :  56.04853893898855
# iteration :  10  loss :  56.04846951372054
# iteration :  20  loss :  56.048400093745066
# iteration :  30  loss :  56.0483306790092
# iteration :  40  loss :  56.04826126951239

# %% [markdown]
# ### Optimal values of Parameters using Trained Model

# %%
m, b
# Out:
# (1.459608061523262, 1.0116688939807819)

# %% [markdown]
# ### Visualize the Data

# %%
fig = plt.figure()

# Generate data for plotting Line
x = np.arange(25, 75)
y = [m * x_i + b for x_i in x]


# plot data and best-fit lines
plt.plot(X, Y, 'o', x, y, '-')
plt.legend(loc='upper left', labels=['data points', 'best-fit line'])

fig.suptitle('Linear Regression : Expected Marks vs Hours of Study', fontsize=18)
plt.xlabel('Hours of Study', fontsize=14)
plt.ylabel('Expected Marks', fontsize=14)
plt.show()
